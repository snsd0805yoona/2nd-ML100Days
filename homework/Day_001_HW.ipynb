# %% [markdown]
# ## 練習時間
# #D1-1:
# #1.我選的這組資料是玩家對於FIFA 19的足球員的屬性做一個統整，從能力值到年齡等等的資料都有，這組資料的重要性在於能提供玩家能力值得參考，
# #使得玩家能預測哪11位球員組成一隊能夠得到最大的效益
# #2.資料是從Kaggle的Data sets裡 Karan Gadiya所提供的 網址:https://www.kaggle.com/karangadiya/fifa19/version/4
# #3.資料的型態有數值、表格、名目屬性
# #4.這組資料想解決的問題能夠先用分類的方式，將不同位置的球員先分類，因此可以用AUC或者是MAP方式來分類
# #D1-2:
# #1.經營一個自由車隊，為了提升業績，我認為核心的問題是:乘客從何處來，一個車隊，沒有乘客，那也就沒有業績。
# #2.資料的蒐集方式可以使用問卷或是調查每輛車的行經路線，可以歸納出哪邊乘客量較大。
# #3.蒐集的資料型態可能會有文字以及圖像
# #4.可以用回歸法去評估載客流量最大的位置是哪裡
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
def mean_squared_error(z,zi):
    """
    計算MSE
    Args:
        -y:實際值
        -yi:估計值
    Return:
        -mse: MSE
    """
    mse=MSE=1/len(z)*sum(pow(z-zi,2))
    return mse

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 254.707
# The Mean absolute error is 13.109
